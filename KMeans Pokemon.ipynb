# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
'''
Data Acquisition
'''
df = pd.read_csv('pokemon.csv')
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
'''
Data preparation
'''

hp = df['hp'].values
at = df['attack'].values
de = df['defense'].values
sp_a = df['sp_attack'].values
sp_d = df['sp_defense'].values
speed = df['speed'].values

x = np.array(list(zip(hp, at, de, sp_a, sp_d, speed)))

# %%
'''
Data visualization
'''

x_coordinate = [i for i in range(len(x)) ]
#Plot by HP
plt.scatter(x[:,0],x_coordinate, s = 30, c = kmeans.labels_)
plt.show()

# %%
#Plot by attack
plt.scatter(x[:,1], x_coordinate, s = 30, c = kmeans.labels_)
plt.show()

# %%
kmeans = KMeans(n_clusters=4).fit(x)
labels = kmeans.labels_

# %%
#Plot by Total
plt.scatter(x.sum(axis=1), x_coordinate, s = 30, c = kmeans.labels_)
plt.show()

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'random')
    kmeans.fit(x)
    print(i,kmeans.inertia_)
    wcss.append(kmeans.inertia_)  
plt.plot(range(1, 11), wcss)
plt.title('O Metodo Elbow')
plt.xlabel('Numero de Clusters')
plt.ylabel('WSS')
plt.show()
# Out:
# 1 4280337.455680399
# 2 2916105.0154616013
# 3 2541949.364398992
# 4 2265122.884142886
# 5 2087144.207573481
# 6 1931887.4981417982
# 7 1830931.792486391
# 8 1709892.41447593
# 9 1631389.8681448265
# 10 1570363.0283990605

# %%
df['total'] = x.sum(axis=1)
df['cluster']  = labels
df[['name', 'cluster', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed', 'total']]
# Out:
#            name  cluster   hp  attack  defense  sp_attack  sp_defense  speed  \
# 0     Bulbasaur        1   45      49       49         65          65     45
# 1       Ivysaur        2   60      62       63         80          80     60
# 2      Venusaur        0   80     100      123        122         120     80
# 3    Charmander        1   39      52       43         60          50     65
# 4    Charmeleon        2   58      64       58         80          65     80
# 5     Charizard        0   78     104       78        159         115    100
# 6      Squirtle        1   44      48       65         50          64     43
# 7     Wartortle        2   59      63       80         65          80     58
# 8     Blastoise        0   79     103      120        135         115     78
# 9      Caterpie        1   45      30       35         20          20     45
# 10      Metapod        1   50      20       55         25          25     30
# ...
